# %% [markdown]
# # Principal component analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('./winequality-white.csv', delimiter=';')
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ## Basic statistics

# %%
#df.iloc[:,:-1].describe()
df.iloc[:,:].describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
rnd_indices = [3399, 1034, 2360, 342, 3701, 3359, 2032, 2117, 1927, 2773, 
               3850, 2049, 3135, 2904, 2376, 1504, 3799, 3484, 1277, 2700, 
               1330, 1870, 1407, 2983, 1526, 3776, 2021, 618, 1878, 2871, 
               512, 3929, 2386, 1897, 781, 1620, 2742, 2512, 2890, 2538, 
               750, 3663, 1169, 1950, 764, 1518, 2787, 2435, 2557, 2073, 
               711, 1088, 3055, 1595, 3756, 2142, 3005, 1243, 2025, 2111, 
               3635, 1453, 3097, 3077, 1731, 916, 2932, 911, 137, 2896, 
               1294, 2638, 2544, 1459, 1704, 3596, 353, 745, 900, 956, 
               3741, 1419, 3727, 2655, 889, 3189, 3636, 2311, 3940, 
               3817, 2574, 3860, 3608, 1498, 987, 359, 1728, 1342, 3468, 72]
plt.figure(figsize=(10,6))
_df = df.iloc[rnd_indices, :]
plt.scatter(_df['volatile acidity'],_df['density'],c=_df['quality'],edgecolors='k',alpha=0.75,s=150)
plt.grid(True)
plt.title("Scatter plot of two features showing the \ncorrelation and class seperation",fontsize=15)
plt.xlabel("volatile acidity",fontsize=15)
plt.ylabel("density",fontsize=15)
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure(figsize=(16,12))
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Wine data set features correlation\n',fontsize=15)
    labels=df.columns
    ax1.set_xticklabels(labels, fontsize=9)
    ax1.set_yticklabels(labels, fontsize=9)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[0.1*i for i in range(-11,11)])
    plt.show()

correlation_matrix(df)
# Out:
# <ipython-input-4-1fbe1159017d>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,fontsize=9)
# <ipython-input-4-1fbe1159017d>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(labels,fontsize=9)

# %% [markdown]
# ## Data scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = df.drop('quality',axis=1)
y = df['quality']

X = scaler.fit_transform(X)

dfx = pd.DataFrame(data=X,columns=df.columns[:-1])

dfx.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172097         -0.081770     0.213280        2.821349  -0.035355
# 1      -0.657501          0.215896     0.048001       -0.944765   0.147747
# 2       1.475751          0.017452     0.543838        0.100282   0.193523
# 3       0.409125         -0.478657    -0.117278        0.415768   0.559727
# 4       0.409125         -0.478657    -0.117278        0.415768   0.559727
# 5       1.475751          0.017452     0.543838        0.100282   0.193523
# 6      -0.776015          0.414339    -1.439511        0.120000  -0.035355
# 7       0.172097         -0.081770     0.213280        2.821349  -0.035355
# 8      -0.657501          0.215896     0.048001       -0.944765   0.147747
# 9       1.475751         -0.577879     0.791757       -0.964483  -0.081131
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# ...

# %%
dfx.describe()
# Out:
#        fixed acidity  volatile acidity   citric acid  residual sugar  \
# count   4.898000e+03      4.898000e+03  4.898000e+03    4.898000e+03
# mean    7.584333e-17      5.196832e-16  6.019639e-16   -1.024542e-16
# std     1.000102e+00      1.000102e+00  1.000102e+00    1.000102e+00
# min    -3.620351e+00     -1.966985e+00 -2.761743e+00   -1.141944e+00
# 25%    -6.575011e-01     -6.771010e-01 -5.304757e-01   -9.250474e-01
# 50%    -6.493106e-02     -1.809917e-01 -1.172780e-01   -2.349217e-01
# 75%     5.276390e-01      4.143393e-01  4.611988e-01    6.918185e-01
# max     8.705106e+00      8.153643e+00  1.095642e+01    1.171411e+01
#
#           chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  4.898000e+03         4.898000e+03          4.898000e+03  4.898000e+03
# mean   3.410456e-16        -4.671641e-17          1.057636e-16  3.220250e-14
# std    1.000102e+00         1.000102e+00          1.000102e+00  1.000102e+00
# ...

# %% [markdown]
# ## PCA class import and analysis

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=None)
dfx_pca = pca.fit(dfx)

# %% [markdown]
# ## Plot of variance explained by each component

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=[i+1 for i in range(len(dfx_pca.explained_variance_ratio_))],
            y=dfx_pca.explained_variance_ratio_,
           s=200, alpha=0.75,c='orange',edgecolor='k')
plt.grid(True)
plt.title("Explained variance ratio of the \nfitted principal component vector\n",fontsize=25)
plt.xlabel("Principal components",fontsize=15)
plt.xticks([i+1 for i in range(len(dfx_pca.explained_variance_ratio_))],fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel("Explained variance ratio",fontsize=15)
plt.show()

# %% [markdown]
# ## Better class separation using principal components

# %%
dfx_trans = pca.transform(dfx)
dfx_trans = pd.DataFrame(data=dfx_trans)
dfx_trans.head(10)

_dfx_trans = dfx_trans.iloc[rnd_indices, :]

# %%
plt.figure(figsize=(10,6))
plt.scatter(_dfx_trans[0],_dfx_trans[1],c=_df['quality'],edgecolors='k',alpha=0.75,s=150)
plt.grid(True)
plt.title("Class separation using first two principal components\n",fontsize=20)
plt.xlabel("Principal component-1",fontsize=15)
plt.ylabel("Principal component-2",fontsize=15)
plt.show()
